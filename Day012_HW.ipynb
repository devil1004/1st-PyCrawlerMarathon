{}

for d in soup.find(class_="part_list_2").find_all('h3'):
    news_type = d.find(class_="tag").text
    request.setdefault(news_type,[])
    request[news_type].append(d.find(class_="date").text + d.find_all('a')[0].text)
request
# Out:
# 字典分類
# {'政治': ['2020/02/02 18:55寒假延長防疫武漢肺炎\u3000蘇貞昌：不容許孩子有任何閃失',
#   '2020/02/02 18:49亂爆隔離地點遭陳時中嗆處置\u3000柯文哲冷回：喔，那就不要講啊',
#   '2020/02/02 17:35武漢肺炎延開學！家長可請「14天防疫假」\u3000勞動部：不得扣全勤',
#   '2020/02/02 17:32郝龍斌：多國支持台灣加入WHO\u3000北京應放下政治成見',
#   '2020/02/02 17:28一天100萬個口罩不夠用！柯文哲喊話中央：要管制就應公開透明',
#   '2020/02/02 17:08影／新北市全面嚴查！侯友宜：抓到口罩酒精囤貨、哄抬物價絕不寬貸',
#   '2020/02/02 17:04影／買不到口罩！侯友宜轟：中央應將生產量、配發量清楚公布',
#   '2020/02/02 16:58武漢台商包機回台安置何處？\u3000柯文哲爆：台北分到陽明山台銀宿舍'],
#  '影劇': ['2020/02/02 18:46暖送500口罩後逃跑...鄧紫棋感動寫「抗疫神曲」：致敬平凡天使！',
#   '2020/02/02 18:23全球瘋搶口罩！史丹利日本旅遊揭「驚人現況」：沒想到更慘',
#   '2020/02/02 18:15尼克選婚紗自曝「冷漠行為」！\u3000Ashly秒變臉泛涙：以前我們不是這樣的',
#   '2020/02/02 17:14雷／朴敘俊嘶吼哭喊「爸爸」！《梨泰院class》ep2前10分鐘超催淚',
#   '2020/02/02 16:55脫線2度昏迷住院「感冒發燒引發肺炎」\u3000楊繡惠心疼曝近況',
#   '2020/02/02 16:24陸男星「出國狂掃16萬片口罩」！\u3000裝40箱人肉托運通關…「購買地點曝光」',
#   '2020/02/02 16:05鄧紫棋把親妹P成蛇精臉！\u3000網神出「姊妹同框原圖」嚇傻…五官97%長一樣'],
#  '地方': ['2020/02/02 18:46「2020愛上鹿野-花現鹿野農遊尋寶趣」\u3000體驗台東農村之美',
#   '2020/02/02 18:37另類「回娘家」\u3000帶第二代回美滿中心報名未婚聯誼',
# ...

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
'''
Your Code
'''
count = []
for n in request.keys():
    count.append([n,len(request[n])])


count.sort(key = lambda s: s[1],reverse=True)
count
# Out:
# [['生活', 28],
#  ['大陸', 10],
#  ['政治', 8],
#  ['國際', 8],
#  ['影劇', 7],
#  ['體育', 7],
#  ['寵物動物', 7],
#  ['地方', 6],
#  ['旅遊', 5],
#  ['社會', 3],
#  ['時尚', 3],
#  ['ET車雲', 2],
#  ['男女', 2],
#  ['房產雲', 2],
#  ['財經', 1],
#  ['健康', 1]]
