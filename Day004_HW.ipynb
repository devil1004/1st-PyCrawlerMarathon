# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
import json

r = requests.get('https://api.github.com/events')
r.text
json.loads(r.text)
# Out:
# [{'id': '11020755430',
#   'type': 'CreateEvent',
#   'actor': {'id': 45013227,
#    'login': 'AwkwardBanana',
#    'display_login': 'AwkwardBanana',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AwkwardBanana',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45013227?'},
#   'repo': {'id': 225709188,
#    'name': 'AwkwardBanana/home',
#    'url': 'https://api.github.com/repos/AwkwardBanana/home'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z'},
#  {'id': '11020755419',
#   'type': 'PushEvent',
#   'actor': {'id': 2267373,
#    'login': 'RobFog',
#    'display_login': 'RobFog',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RobFog',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2267373?'},
#   'repo': {'id': 216910154,
#    'name': 'adium/Adium-2',
#    'url': 'https://api.github.com/repos/adium/Adium-2'},
#   'payload': {'push_id': 4360043363,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/Sandboxing',
#    'head': 'd6078e7e20f17a6f45798e6186d6fddda7124f32',
#    'before': 'd6078e7e20f17a6f45798e6186d6fddda7124f32',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z',
#   'org': {'id': 2288688,
#    'login': 'adium',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adium',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2288688?'}},
#  {'id': '11020755424',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 23327384,
#    'login': 'ISS-Mimic',
#    'display_login': 'ISS-Mimic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ISS-Mimic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23327384?'},
#   'repo': {'id': 73144576,
#    'name': 'ISS-Mimic/Mimic',
#    'url': 'https://api.github.com/repos/ISS-Mimic/Mimic'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ISS-Mimic/Mimic/issues/137',
#     'repository_url': 'https://api.github.com/repos/ISS-Mimic/Mimic',
#     'labels_url': 'https://api.github.com/repos/ISS-Mimic/Mimic/issues/137/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ISS-Mimic/Mimic/issues/137/comments',
#     'events_url': 'https://api.github.com/repos/ISS-Mimic/Mimic/issues/137/events',
#     'html_url': 'https://github.com/ISS-Mimic/Mimic/issues/137',
#     'id': 532541912,
#     'node_id': 'MDU6SXNzdWU1MzI1NDE5MTI=',
#     'number': 137,
#     'title': 'Information needed: Telemetry use for real-time simulation in SpaceCRAFT VR Platform',
#     'user': {'login': 'connorjak',
#      'id': 19719887,
#      'node_id': 'MDQ6VXNlcjE5NzE5ODg3',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/19719887?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/connorjak',
#      'html_url': 'https://github.com/connorjak',
#      'followers_url': 'https://api.github.com/users/connorjak/followers',
#      'following_url': 'https://api.github.com/users/connorjak/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/connorjak/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/connorjak/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/connorjak/subscriptions',
#      'organizations_url': 'https://api.github.com/users/connorjak/orgs',
#      'repos_url': 'https://api.github.com/users/connorjak/repos',
#      'events_url': 'https://api.github.com/users/connorjak/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/connorjak/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1715651854,
#       'node_id': 'MDU6TGFiZWwxNzE1NjUxODU0',
#       'url': 'https://api.github.com/repos/ISS-Mimic/Mimic/labels/Question',
#       'name': 'Question',
#       'color': '56d3ae',
#       'default': False,
#       'description': 'Any requests for more information or clarification'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 10,
#     'created_at': '2019-12-04T09:04:16Z',
#     'updated_at': '2019-12-05T15:10:47Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'Hello,\r\n\r\nI am Connor Jakubik, System Architecture Team Lead at SpaceCRAFT VR at Texas A&M University. We are putting together a new, open-source integrated simulation platform that is releasing somewhat soon. For one of our example simulations, we would like to have real-time ISS telemetry feeding the state of our ISS model. In particular, we would like to at least have the positions of the solar panels and radiators, but the more parameters the merrier.\r\n\r\nUpon glancing over this codebase, it looks like the majority of this code is Javascript and Python. While we are working on eventual Python support, we use C++ for the majority of our code. How should we proceed with trying to get this data stream to C++? One idea that comes to mind is using a file / named pipe for communicating events.'},
#    'comment': {'url': 'https://api.github.com/repos/ISS-Mimic/Mimic/issues/comments/562171256',
#     'html_url': 'https://github.com/ISS-Mimic/Mimic/issues/137#issuecomment-562171256',
#     'issue_url': 'https://api.github.com/repos/ISS-Mimic/Mimic/issues/137',
#     'id': 562171256,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MjE3MTI1Ng==',
#     'user': {'login': 'ISS-Mimic',
#      'id': 23327384,
#      'node_id': 'MDQ6VXNlcjIzMzI3Mzg0',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/23327384?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ISS-Mimic',
#      'html_url': 'https://github.com/ISS-Mimic',
#      'followers_url': 'https://api.github.com/users/ISS-Mimic/followers',
#      'following_url': 'https://api.github.com/users/ISS-Mimic/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ISS-Mimic/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ISS-Mimic/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ISS-Mimic/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ISS-Mimic/orgs',
#      'repos_url': 'https://api.github.com/users/ISS-Mimic/repos',
#      'events_url': 'https://api.github.com/users/ISS-Mimic/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ISS-Mimic/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-05T15:10:47Z',
#     'updated_at': '2019-12-05T15:10:47Z',
#     'author_association': 'OWNER',
#     'body': 'I forgot to mention also that we delete the database file and create it again from scratch every single time the program runs to solve what I believe was a similar problem. That\'s why we have that database initialize script which gets called on program startup.\r\n\r\n"The occasional LOS of station data isn\'t helping either." - You have no idea how often we say this :P'}},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z'},
#  {'id': '11020755416',
#   'type': 'PushEvent',
#   'actor': {'id': 2914091,
#    'login': 'nbucknor',
#    'display_login': 'nbucknor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nbucknor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2914091?'},
#   'repo': {'id': 112360651,
#    'name': 'cfpb/teachers-digital-platform',
#    'url': 'https://api.github.com/repos/cfpb/teachers-digital-platform'},
#   'payload': {'push_id': 4360043372,
#    'size': 7,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9cdc5ef59115336599f7a57a4e3a8546b9fb59fe',
#    'before': '9de4d17aa23c2982b18b058b70e6fd3185aab6d9',
#    'commits': [{'sha': 'b68a4ad8c289ad73513c67d63b32cc3844392a42',
#      'author': {'email': 'nbucknor@forumone.com', 'name': 'Norman Bucknor'},
#      'message': '[TDP] Add Similar Activities block to Activity detail page',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cfpb/teachers-digital-platform/commits/b68a4ad8c289ad73513c67d63b32cc3844392a42'},
#     {'sha': 'b0afc638b3038482f59b69af12e7071aa6aeac0c',
#      'author': {'email': 'nbucknor@forumone.com', 'name': 'Norman Bucknor'},
#      'message': '[TDP] fixing linting issues in pages.py',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cfpb/teachers-digital-platform/commits/b0afc638b3038482f59b69af12e7071aa6aeac0c'},
#     {'sha': '62bfd342f2b9a3ce4a52550236dbdf99a27a05dd',
#      'author': {'email': 'nbucknor@forumone.com', 'name': 'Norman Bucknor'},
#      'message': '[TDP] adding unit tests for get_grade_level_ids() and get_subtopic_ids()',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cfpb/teachers-digital-platform/commits/62bfd342f2b9a3ce4a52550236dbdf99a27a05dd'},
#     {'sha': 'cce2c53dc1e662b8c0ab4243eb78a9d7fbb81317',
#      'author': {'email': 'nbucknor@users.noreply.github.com',
#       'name': 'Norman Bucknor'},
#      'message': 'Apply suggestions from code review\n\nCo-Authored-By: Andy Chosak <andy.chosak@cfpb.gov>\nCo-Authored-By: Scott Cranfill <scott.cranfill@cfpb.gov>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cfpb/teachers-digital-platform/commits/cce2c53dc1e662b8c0ab4243eb78a9d7fbb81317'},
#     {'sha': '35cfc03a2a9a9b50a019dde6798fabc14b3278dc',
#      'author': {'email': 'nbucknor@forumone.com', 'name': 'Norman Bucknor'},
#      'message': '[TDP] updating unit tests to use correct assertions',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cfpb/teachers-digital-platform/commits/35cfc03a2a9a9b50a019dde6798fabc14b3278dc'},
#     {'sha': 'dde67cbc97ddf0fd78154b2d3494a3c92e4da8a8',
#      'author': {'email': 'nbucknor@forumone.com', 'name': 'Norman Bucknor'},
#      'message': '[TDP] moved activity url into function and added unit tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cfpb/teachers-digital-platform/commits/dde67cbc97ddf0fd78154b2d3494a3c92e4da8a8'},
#     {'sha': '9cdc5ef59115336599f7a57a4e3a8546b9fb59fe',
#      'author': {'email': 'nbucknor@users.noreply.github.com',
#       'name': 'Norman Bucknor'},
#      'message': 'Merge pull request #362 from cfpb/TDP-similar-activities-block\n\n[TDP] similar activities block',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cfpb/teachers-digital-platform/commits/9cdc5ef59115336599f7a57a4e3a8546b9fb59fe'}]},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z',
#   'org': {'id': 1071563,
#    'login': 'cfpb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cfpb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1071563?'}},
#  {'id': '11020755402',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 2130305,
#    'login': 'turboMaCk',
#    'display_login': 'turboMaCk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/turboMaCk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2130305?'},
#   'repo': {'id': 158972821,
#    'name': 'turboMaCk/planning-game',
#    'url': 'https://api.github.com/repos/turboMaCk/planning-game'},
#   'payload': {'action': 'opened',
#    'number': 75,
#    'pull_request': {'url': 'https://api.github.com/repos/turboMaCk/planning-game/pulls/75',
#     'id': 349490684,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ5NDkwNjg0',
#     'html_url': 'https://github.com/turboMaCk/planning-game/pull/75',
#     'diff_url': 'https://github.com/turboMaCk/planning-game/pull/75.diff',
#     'patch_url': 'https://github.com/turboMaCk/planning-game/pull/75.patch',
#     'issue_url': 'https://api.github.com/repos/turboMaCk/planning-game/issues/75',
#     'number': 75,
#     'state': 'open',
#     'locked': False,
#     'title': 'tiny improvements',
#     'user': {'login': 'turboMaCk',
#      'id': 2130305,
#      'node_id': 'MDQ6VXNlcjIxMzAzMDU=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/2130305?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/turboMaCk',
#      'html_url': 'https://github.com/turboMaCk',
#      'followers_url': 'https://api.github.com/users/turboMaCk/followers',
#      'following_url': 'https://api.github.com/users/turboMaCk/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/turboMaCk/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/turboMaCk/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/turboMaCk/subscriptions',
#      'organizations_url': 'https://api.github.com/users/turboMaCk/orgs',
#      'repos_url': 'https://api.github.com/users/turboMaCk/repos',
#      'events_url': 'https://api.github.com/users/turboMaCk/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/turboMaCk/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-12-05T15:10:46Z',
#     'updated_at': '2019-12-05T15:10:46Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/turboMaCk/planning-game/pulls/75/commits',
#     'review_comments_url': 'https://api.github.com/repos/turboMaCk/planning-game/pulls/75/comments',
#     'review_comment_url': 'https://api.github.com/repos/turboMaCk/planning-game/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/turboMaCk/planning-game/issues/75/comments',
#     'statuses_url': 'https://api.github.com/repos/turboMaCk/planning-game/statuses/670ae4b7b939057f9df3b7a2458e8d52b17e96ea',
#     'head': {'label': 'turboMaCk:chore/updates',
#      'ref': 'chore/updates',
#      'sha': '670ae4b7b939057f9df3b7a2458e8d52b17e96ea',
#      'user': {'login': 'turboMaCk',
#       'id': 2130305,
#       'node_id': 'MDQ6VXNlcjIxMzAzMDU=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/2130305?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/turboMaCk',
#       'html_url': 'https://github.com/turboMaCk',
#       'followers_url': 'https://api.github.com/users/turboMaCk/followers',
#       'following_url': 'https://api.github.com/users/turboMaCk/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/turboMaCk/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/turboMaCk/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/turboMaCk/subscriptions',
#       'organizations_url': 'https://api.github.com/users/turboMaCk/orgs',
#       'repos_url': 'https://api.github.com/users/turboMaCk/repos',
#       'events_url': 'https://api.github.com/users/turboMaCk/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/turboMaCk/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 158972821,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTg5NzI4MjE=',
#       'name': 'planning-game',
#       'full_name': 'turboMaCk/planning-game',
#       'private': False,
#       'owner': {'login': 'turboMaCk',
#        'id': 2130305,
#        'node_id': 'MDQ6VXNlcjIxMzAzMDU=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/2130305?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/turboMaCk',
#        'html_url': 'https://github.com/turboMaCk',
#        'followers_url': 'https://api.github.com/users/turboMaCk/followers',
#        'following_url': 'https://api.github.com/users/turboMaCk/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/turboMaCk/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/turboMaCk/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/turboMaCk/subscriptions',
#        'organizations_url': 'https://api.github.com/users/turboMaCk/orgs',
#        'repos_url': 'https://api.github.com/users/turboMaCk/repos',
#        'events_url': 'https://api.github.com/users/turboMaCk/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/turboMaCk/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/turboMaCk/planning-game',
#       'description': 'Planning tool for remote teams written in Haskell & Elm',
#       'fork': False,
#       'url': 'https://api.github.com/repos/turboMaCk/planning-game',
#       'forks_url': 'https://api.github.com/repos/turboMaCk/planning-game/forks',
#       'keys_url': 'https://api.github.com/repos/turboMaCk/planning-game/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/turboMaCk/planning-game/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/turboMaCk/planning-game/teams',
#       'hooks_url': 'https://api.github.com/repos/turboMaCk/planning-game/hooks',
#       'issue_events_url': 'https://api.github.com/repos/turboMaCk/planning-game/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/turboMaCk/planning-game/events',
#       'assignees_url': 'https://api.github.com/repos/turboMaCk/planning-game/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/turboMaCk/planning-game/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/turboMaCk/planning-game/tags',
#       'blobs_url': 'https://api.github.com/repos/turboMaCk/planning-game/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/turboMaCk/planning-game/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/turboMaCk/planning-game/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/turboMaCk/planning-game/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/turboMaCk/planning-game/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/turboMaCk/planning-game/languages',
#       'stargazers_url': 'https://api.github.com/repos/turboMaCk/planning-game/stargazers',
#       'contributors_url': 'https://api.github.com/repos/turboMaCk/planning-game/contributors',
#       'subscribers_url': 'https://api.github.com/repos/turboMaCk/planning-game/subscribers',
#       'subscription_url': 'https://api.github.com/repos/turboMaCk/planning-game/subscription',
#       'commits_url': 'https://api.github.com/repos/turboMaCk/planning-game/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/turboMaCk/planning-game/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/turboMaCk/planning-game/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/turboMaCk/planning-game/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/turboMaCk/planning-game/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/turboMaCk/planning-game/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/turboMaCk/planning-game/merges',
#       'archive_url': 'https://api.github.com/repos/turboMaCk/planning-game/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/turboMaCk/planning-game/downloads',
#       'issues_url': 'https://api.github.com/repos/turboMaCk/planning-game/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/turboMaCk/planning-game/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/turboMaCk/planning-game/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/turboMaCk/planning-game/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/turboMaCk/planning-game/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/turboMaCk/planning-game/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/turboMaCk/planning-game/deployments',
#       'created_at': '2018-11-24T20:54:45Z',
#       'updated_at': '2019-11-02T21:00:31Z',
#       'pushed_at': '2019-12-05T15:10:36Z',
#       'git_url': 'git://github.com/turboMaCk/planning-game.git',
#       'ssh_url': 'git@github.com:turboMaCk/planning-game.git',
#       'clone_url': 'https://github.com/turboMaCk/planning-game.git',
#       'svn_url': 'https://github.com/turboMaCk/planning-game',
#       'homepage': 'https://planning-game.com',
#       'size': 5625,
#       'stargazers_count': 15,
#       'watchers_count': 15,
#       'language': 'Elm',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 8,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'forks': 1,
#       'open_issues': 8,
#       'watchers': 15,
#       'default_branch': 'master'}},
#     'base': {'label': 'turboMaCk:master',
#      'ref': 'master',
#      'sha': 'b65bc7d284bdb23f624aeb675cd9cdf72acdd292',
#      'user': {'login': 'turboMaCk',
#       'id': 2130305,
#       'node_id': 'MDQ6VXNlcjIxMzAzMDU=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/2130305?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/turboMaCk',
#       'html_url': 'https://github.com/turboMaCk',
#       'followers_url': 'https://api.github.com/users/turboMaCk/followers',
#       'following_url': 'https://api.github.com/users/turboMaCk/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/turboMaCk/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/turboMaCk/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/turboMaCk/subscriptions',
#       'organizations_url': 'https://api.github.com/users/turboMaCk/orgs',
#       'repos_url': 'https://api.github.com/users/turboMaCk/repos',
#       'events_url': 'https://api.github.com/users/turboMaCk/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/turboMaCk/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 158972821,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNTg5NzI4MjE=',
#       'name': 'planning-game',
#       'full_name': 'turboMaCk/planning-game',
#       'private': False,
#       'owner': {'login': 'turboMaCk',
#        'id': 2130305,
#        'node_id': 'MDQ6VXNlcjIxMzAzMDU=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/2130305?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/turboMaCk',
#        'html_url': 'https://github.com/turboMaCk',
#        'followers_url': 'https://api.github.com/users/turboMaCk/followers',
#        'following_url': 'https://api.github.com/users/turboMaCk/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/turboMaCk/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/turboMaCk/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/turboMaCk/subscriptions',
#        'organizations_url': 'https://api.github.com/users/turboMaCk/orgs',
#        'repos_url': 'https://api.github.com/users/turboMaCk/repos',
#        'events_url': 'https://api.github.com/users/turboMaCk/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/turboMaCk/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/turboMaCk/planning-game',
#       'description': 'Planning tool for remote teams written in Haskell & Elm',
#       'fork': False,
#       'url': 'https://api.github.com/repos/turboMaCk/planning-game',
#       'forks_url': 'https://api.github.com/repos/turboMaCk/planning-game/forks',
#       'keys_url': 'https://api.github.com/repos/turboMaCk/planning-game/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/turboMaCk/planning-game/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/turboMaCk/planning-game/teams',
#       'hooks_url': 'https://api.github.com/repos/turboMaCk/planning-game/hooks',
#       'issue_events_url': 'https://api.github.com/repos/turboMaCk/planning-game/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/turboMaCk/planning-game/events',
#       'assignees_url': 'https://api.github.com/repos/turboMaCk/planning-game/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/turboMaCk/planning-game/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/turboMaCk/planning-game/tags',
#       'blobs_url': 'https://api.github.com/repos/turboMaCk/planning-game/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/turboMaCk/planning-game/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/turboMaCk/planning-game/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/turboMaCk/planning-game/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/turboMaCk/planning-game/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/turboMaCk/planning-game/languages',
#       'stargazers_url': 'https://api.github.com/repos/turboMaCk/planning-game/stargazers',
#       'contributors_url': 'https://api.github.com/repos/turboMaCk/planning-game/contributors',
#       'subscribers_url': 'https://api.github.com/repos/turboMaCk/planning-game/subscribers',
#       'subscription_url': 'https://api.github.com/repos/turboMaCk/planning-game/subscription',
#       'commits_url': 'https://api.github.com/repos/turboMaCk/planning-game/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/turboMaCk/planning-game/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/turboMaCk/planning-game/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/turboMaCk/planning-game/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/turboMaCk/planning-game/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/turboMaCk/planning-game/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/turboMaCk/planning-game/merges',
#       'archive_url': 'https://api.github.com/repos/turboMaCk/planning-game/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/turboMaCk/planning-game/downloads',
#       'issues_url': 'https://api.github.com/repos/turboMaCk/planning-game/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/turboMaCk/planning-game/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/turboMaCk/planning-game/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/turboMaCk/planning-game/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/turboMaCk/planning-game/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/turboMaCk/planning-game/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/turboMaCk/planning-game/deployments',
#       'created_at': '2018-11-24T20:54:45Z',
#       'updated_at': '2019-11-02T21:00:31Z',
#       'pushed_at': '2019-12-05T15:10:36Z',
#       'git_url': 'git://github.com/turboMaCk/planning-game.git',
#       'ssh_url': 'git@github.com:turboMaCk/planning-game.git',
#       'clone_url': 'https://github.com/turboMaCk/planning-game.git',
#       'svn_url': 'https://github.com/turboMaCk/planning-game',
#       'homepage': 'https://planning-game.com',
#       'size': 5625,
#       'stargazers_count': 15,
#       'watchers_count': 15,
#       'language': 'Elm',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 8,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'forks': 1,
#       'open_issues': 8,
#       'watchers': 15,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/turboMaCk/planning-game/pulls/75'},
#      'html': {'href': 'https://github.com/turboMaCk/planning-game/pull/75'},
#      'issue': {'href': 'https://api.github.com/repos/turboMaCk/planning-game/issues/75'},
#      'comments': {'href': 'https://api.github.com/repos/turboMaCk/planning-game/issues/75/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/turboMaCk/planning-game/pulls/75/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/turboMaCk/planning-game/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/turboMaCk/planning-game/pulls/75/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/turboMaCk/planning-game/statuses/670ae4b7b939057f9df3b7a2458e8d52b17e96ea'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'draft',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 3,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z'},
#  {'id': '11020755403',
#   'type': 'CreateEvent',
#   'actor': {'id': 12769926,
#    'login': 'LRossman',
#    'display_login': 'LRossman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LRossman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12769926?'},
#   'repo': {'id': 24166957,
#    'name': 'OpenWaterAnalytics/EPANET',
#    'url': 'https://api.github.com/repos/OpenWaterAnalytics/EPANET'},
#   'payload': {'ref': 'lrossman-Pump_Bug_Fix',
#    'ref_type': 'branch',
#    'master_branch': 'dev',
#    'description': 'The Water Distribution System Hydraulic and Water Quality Analysis Toolkit',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z',
#   'org': {'id': 2392819,
#    'login': 'OpenWaterAnalytics',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/OpenWaterAnalytics',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2392819?'}},
#  {'id': '11020755398',
#   'type': 'PushEvent',
#   'actor': {'id': 4265377,
#    'login': 'halomoan',
#    'display_login': 'halomoan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/halomoan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4265377?'},
#   'repo': {'id': 218315692,
#    'name': 'halomoan/RECNMANAGE',
#    'url': 'https://api.github.com/repos/halomoan/RECNMANAGE'},
#   'payload': {'push_id': 4360043361,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9d626c0df18da70fc24d5924099f40d498dfbbc9',
#    'before': '94a60667e55874034a44599806c9adc9a07368e6',
#    'commits': [{'sha': '9d626c0df18da70fc24d5924099f40d498dfbbc9',
#      'author': {'email': 'halomoan@gmail.com', 'name': 'Halomoan'},
#      'message': 'Home Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/halomoan/RECNMANAGE/commits/9d626c0df18da70fc24d5924099f40d498dfbbc9'}]},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z'},
#  {'id': '11020755396',
#   'type': 'WatchEvent',
#   'actor': {'id': 7886392,
#    'login': 'mengrennwpu',
#    'display_login': 'mengrennwpu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mengrennwpu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7886392?'},
#   'repo': {'id': 83999700,
#    'name': 'sdmg15/Best-websites-a-programmer-should-visit',
#    'url': 'https://api.github.com/repos/sdmg15/Best-websites-a-programmer-should-visit'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z'},
#  {'id': '11020755342',
#   'type': 'PushEvent',
#   'actor': {'id': 16837285,
#    'login': 'robodoo',
#    'display_login': 'robodoo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/robodoo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16837285?'},
#   'repo': {'id': 19745004,
#    'name': 'odoo/odoo',
#    'url': 'https://api.github.com/repos/odoo/odoo'},
#   'payload': {'push_id': 4360043298,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/tmp.saas-13.1',
#    'head': 'e3dd6b1ffe43ab4ac992e6582d6c41f17b5dc734',
#    'before': '42ae9ce544605314d969ae1210245f5b5bbf2628',
#    'commits': [{'sha': 'e3dd6b1ffe43ab4ac992e6582d6c41f17b5dc734',
#      'author': {'email': 'qle@odoo.com', 'name': 'lejeune quentin'},
#      'message': '[FIX] point_of_sale: Fix access point for IoT Box\n\nWhen the box is in "access point" it calls the function \'get_wifi_essid\'\nat every ping => ~ 3 seconds.\nSo after a few moments the network card blocks and turns off.\nNow we redirect the user to the \'/steps\' route that only executes the function once.\n\ncloses odoo/odoo#41409\n\nX-original-commit: b5020a4471666cb53398077db4e856d1c60245a9\nSigned-off-by: Quentin Lejeune (qle) <qle@odoo.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/odoo/odoo/commits/e3dd6b1ffe43ab4ac992e6582d6c41f17b5dc734'}]},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z',
#   'org': {'id': 6368483,
#    'login': 'odoo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/odoo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6368483?'}},
#  {'id': '11020755377',
#   'type': 'ForkEvent',
#   'actor': {'id': 15694761,
#    'login': 'kbanse',
#    'display_login': 'kbanse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kbanse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15694761?'},
#   'repo': {'id': 12087157,
#    'name': 'heathcliff/css3-mediaqueries-js',
#    'url': 'https://api.github.com/repos/heathcliff/css3-mediaqueries-js'},
#   'payload': {'forkee': {'id': 226129216,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjYxMjkyMTY=',
#     'name': 'css3-mediaqueries-js',
#     'full_name': 'kbanse/css3-mediaqueries-js',
#     'private': False,
#     'owner': {'login': 'kbanse',
#      'id': 15694761,
#      'node_id': 'MDQ6VXNlcjE1Njk0NzYx',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/15694761?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kbanse',
#      'html_url': 'https://github.com/kbanse',
#      'followers_url': 'https://api.github.com/users/kbanse/followers',
#      'following_url': 'https://api.github.com/users/kbanse/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kbanse/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kbanse/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kbanse/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kbanse/orgs',
#      'repos_url': 'https://api.github.com/users/kbanse/repos',
#      'events_url': 'https://api.github.com/users/kbanse/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kbanse/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/kbanse/css3-mediaqueries-js',
#     'description': 'css3-mediaqueries.js: make CSS3 Media Queries work in all browsers (JavaScript library)',
#     'fork': True,
#     'url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js',
#     'forks_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/forks',
#     'keys_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/teams',
#     'hooks_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/hooks',
#     'issue_events_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/events',
#     'assignees_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/tags',
#     'blobs_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/languages',
#     'stargazers_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/stargazers',
#     'contributors_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/contributors',
#     'subscribers_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/subscribers',
#     'subscription_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/subscription',
#     'commits_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/merges',
#     'archive_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/downloads',
#     'issues_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/kbanse/css3-mediaqueries-js/deployments',
#     'created_at': '2019-12-05T15:10:46Z',
#     'updated_at': '2019-08-07T12:33:20Z',
#     'pushed_at': '2013-08-13T17:13:44Z',
#     'git_url': 'git://github.com/kbanse/css3-mediaqueries-js.git',
#     'ssh_url': 'git@github.com:kbanse/css3-mediaqueries-js.git',
#     'clone_url': 'https://github.com/kbanse/css3-mediaqueries-js.git',
#     'svn_url': 'https://github.com/kbanse/css3-mediaqueries-js',
#     'homepage': None,
#     'size': 64,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z'},
#  {'id': '11020755365',
#   'type': 'PushEvent',
#   'actor': {'id': 46935456,
#    'login': 'epalermo92',
#    'display_login': 'epalermo92',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/epalermo92',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46935456?'},
#   'repo': {'id': 225486772,
#    'name': 'epalermo92/MarsRoverKata',
#    'url': 'https://api.github.com/repos/epalermo92/MarsRoverKata'},
#   'payload': {'push_id': 4360043342,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a642e40b217f7ec0107f2441ad0225362a596955',
#    'before': 'd55e868757edf35f4e9b0e7bf302e9b8f5363035',
#    'commits': [{'sha': 'a642e40b217f7ec0107f2441ad0225362a596955',
#      'author': {'email': 'emanuele.palermo@facile.it', 'name': 'emanuele'},
#      'message': 'implementing checklimits function and README modified',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/epalermo92/MarsRoverKata/commits/a642e40b217f7ec0107f2441ad0225362a596955'}]},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z'},
#  {'id': '11020755369',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 314009,
#    'login': 'nathanielks',
#    'display_login': 'nathanielks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nathanielks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/314009?'},
#   'repo': {'id': 14574404,
#    'name': 'humanmade/S3-Uploads',
#    'url': 'https://api.github.com/repos/humanmade/S3-Uploads'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/humanmade/S3-Uploads/issues/340',
#     'repository_url': 'https://api.github.com/repos/humanmade/S3-Uploads',
#     'labels_url': 'https://api.github.com/repos/humanmade/S3-Uploads/issues/340/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/humanmade/S3-Uploads/issues/340/comments',
#     'events_url': 'https://api.github.com/repos/humanmade/S3-Uploads/issues/340/events',
#     'html_url': 'https://github.com/humanmade/S3-Uploads/pull/340',
#     'id': 488025929,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzEzMTM0Mjc2',
#     'number': 340,
#     'title': 'Create a temporary file and use it during verification via CLI',
#     'user': {'login': 'ocean90',
#      'id': 617637,
#      'node_id': 'MDQ6VXNlcjYxNzYzNw==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/617637?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ocean90',
#      'html_url': 'https://github.com/ocean90',
#      'followers_url': 'https://api.github.com/users/ocean90/followers',
#      'following_url': 'https://api.github.com/users/ocean90/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ocean90/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ocean90/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ocean90/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ocean90/orgs',
#      'repos_url': 'https://api.github.com/users/ocean90/repos',
#      'events_url': 'https://api.github.com/users/ocean90/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ocean90/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-09-02T06:46:54Z',
#     'updated_at': '2019-12-05T15:10:47Z',
#     'closed_at': '2019-12-05T15:10:46Z',
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/humanmade/S3-Uploads/pulls/340',
#      'html_url': 'https://github.com/humanmade/S3-Uploads/pull/340',
#      'diff_url': 'https://github.com/humanmade/S3-Uploads/pull/340.diff',
#      'patch_url': 'https://github.com/humanmade/S3-Uploads/pull/340.patch'},
#     'body': 'Since the test folder is no longer included in production builds the verification currently fails due to the missing image. This PR replaces the use of the image with a temporary file.\r\n\r\nFixes #309.\r\nFixes #332.'},
#    'comment': {'url': 'https://api.github.com/repos/humanmade/S3-Uploads/issues/comments/562171252',
#     'html_url': 'https://github.com/humanmade/S3-Uploads/pull/340#issuecomment-562171252',
#     'issue_url': 'https://api.github.com/repos/humanmade/S3-Uploads/issues/340',
#     'id': 562171252,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MjE3MTI1Mg==',
#     'user': {'login': 'nathanielks',
#      'id': 314009,
#      'node_id': 'MDQ6VXNlcjMxNDAwOQ==',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/314009?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nathanielks',
#      'html_url': 'https://github.com/nathanielks',
#      'followers_url': 'https://api.github.com/users/nathanielks/followers',
#      'following_url': 'https://api.github.com/users/nathanielks/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nathanielks/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nathanielks/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nathanielks/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nathanielks/orgs',
#      'repos_url': 'https://api.github.com/users/nathanielks/repos',
#      'events_url': 'https://api.github.com/users/nathanielks/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nathanielks/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-05T15:10:46Z',
#     'updated_at': '2019-12-05T15:10:46Z',
#     'author_association': 'MEMBER',
#     'body': 'Closing in favor of https://github.com/humanmade/S3-Uploads/pull/357. Apologies again!'}},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z',
#   'org': {'id': 644666,
#    'login': 'humanmade',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/humanmade',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/644666?'}},
#  {'id': '11020755359',
#   'type': 'PushEvent',
#   'actor': {'id': 46415365,
#    'login': 'BastianSkalit',
#    'display_login': 'BastianSkalit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BastianSkalit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46415365?'},
#   'repo': {'id': 223401860,
#    'name': 'BastianSkalit/belajar_js',
#    'url': 'https://api.github.com/repos/BastianSkalit/belajar_js'},
#   'payload': {'push_id': 4360043351,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/update',
#    'head': 'c5f6a0fc527122d03ca5e214ed2a00c55582485f',
#    'before': '8fa0186d375b1f98ec76f572d37f98c8e0318e2e',
#    'commits': [{'sha': 'c5f6a0fc527122d03ca5e214ed2a00c55582485f',
#      'author': {'email': 'simanungkalitbastian@gmail.com',
#       'name': 'BastianSkalit'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/BastianSkalit/belajar_js/commits/c5f6a0fc527122d03ca5e214ed2a00c55582485f'}]},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z'},
#  {'id': '11020755345',
#   'type': 'PushEvent',
#   'actor': {'id': 57849985,
#    'login': 'ssbuilder01selfstudy',
#    'display_login': 'ssbuilder01selfstudy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ssbuilder01selfstudy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57849985?'},
#   'repo': {'id': 223545451,
#    'name': 'getselfstudy/builder-course-5dd8a805bb3389bf733b8734',
#    'url': 'https://api.github.com/repos/getselfstudy/builder-course-5dd8a805bb3389bf733b8734'},
#   'payload': {'push_id': 4360043323,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '211bc691bdf6c3deac6896460bf39eef48ea3ca9',
#    'before': '001503ea08cc6151625708a7269fba31bad4b944',
#    'commits': [{'sha': '211bc691bdf6c3deac6896460bf39eef48ea3ca9',
#      'author': {'email': 'admin@selfstudy.com', 'name': 'Admin'},
#      'message': 'Update 5dd8a805bb3389bf733b8734 lessons/ISSA2lbwR7-UUoVlgqbd4g.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/getselfstudy/builder-course-5dd8a805bb3389bf733b8734/commits/211bc691bdf6c3deac6896460bf39eef48ea3ca9'}]},
#   'public': True,
#   'created_at': '2019-12-05T15:10:47Z',
#   'org': {'id': 40636471,
#    'login': 'getselfstudy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/getselfstudy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40636471?'}},
#  {'id': '11020755354',
#   'type': 'CreateEvent',
#   'actor': {'id': 46410487,
#    'login': 'luizviana',
#    'display_login': 'luizviana',
# ...
#       'created_at': '2015-06-18T12:16:05Z',
#       'updated_at': '2019-12-04T18:12:02Z',
#       'pushed_at': '2019-12-05T15:10:01Z',
#       'git_url': 'git://github.com/canalplus/rx-player.git',
#       'ssh_url': 'git@github.com:canalplus/rx-player.git',
#       'clone_url': 'https://github.com/canalplus/rx-player.git',
#       'svn_url': 'https://github.com/canalplus/rx-player',
#       'homepage': 'https://developers.canal-plus.com/rx-player/',
#       'size': 106211,
#       'stargazers_count': 455,
#       'watchers_count': 455,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 64,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 18,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 64,
#       'open_issues': 18,
#       'watchers': 455,
#       'default_branch': 'master'}},
#     'base': {'label': 'canalplus:release/v3.17.0',
#      'ref': 'release/v3.17.0',
#      'sha': '0a8125cc604d0e49c75a567240ee84e4b20a2321',
#      'user': {'login': 'canalplus',
#       'id': 2371279,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIzNzEyNzk=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/2371279?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/canalplus',
#       'html_url': 'https://github.com/canalplus',
#       'followers_url': 'https://api.github.com/users/canalplus/followers',
#       'following_url': 'https://api.github.com/users/canalplus/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/canalplus/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/canalplus/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/canalplus/subscriptions',
#       'organizations_url': 'https://api.github.com/users/canalplus/orgs',
#       'repos_url': 'https://api.github.com/users/canalplus/repos',
#       'events_url': 'https://api.github.com/users/canalplus/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/canalplus/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 37657658,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzY1NzY1OA==',
#       'name': 'rx-player',
#       'full_name': 'canalplus/rx-player',
#       'private': False,
#       'owner': {'login': 'canalplus',
#        'id': 2371279,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIzNzEyNzk=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/2371279?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/canalplus',
#        'html_url': 'https://github.com/canalplus',
#        'followers_url': 'https://api.github.com/users/canalplus/followers',
#        'following_url': 'https://api.github.com/users/canalplus/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/canalplus/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/canalplus/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/canalplus/subscriptions',
#        'organizations_url': 'https://api.github.com/users/canalplus/orgs',
#        'repos_url': 'https://api.github.com/users/canalplus/repos',
#        'events_url': 'https://api.github.com/users/canalplus/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/canalplus/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/canalplus/rx-player',
#       'description': 'DASH/Smooth HTML5 Video Player',
#       'fork': False,
#       'url': 'https://api.github.com/repos/canalplus/rx-player',
#       'forks_url': 'https://api.github.com/repos/canalplus/rx-player/forks',
#       'keys_url': 'https://api.github.com/repos/canalplus/rx-player/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/canalplus/rx-player/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/canalplus/rx-player/teams',
#       'hooks_url': 'https://api.github.com/repos/canalplus/rx-player/hooks',
#       'issue_events_url': 'https://api.github.com/repos/canalplus/rx-player/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/canalplus/rx-player/events',
#       'assignees_url': 'https://api.github.com/repos/canalplus/rx-player/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/canalplus/rx-player/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/canalplus/rx-player/tags',
#       'blobs_url': 'https://api.github.com/repos/canalplus/rx-player/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/canalplus/rx-player/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/canalplus/rx-player/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/canalplus/rx-player/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/canalplus/rx-player/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/canalplus/rx-player/languages',
#       'stargazers_url': 'https://api.github.com/repos/canalplus/rx-player/stargazers',
#       'contributors_url': 'https://api.github.com/repos/canalplus/rx-player/contributors',
#       'subscribers_url': 'https://api.github.com/repos/canalplus/rx-player/subscribers',
#       'subscription_url': 'https://api.github.com/repos/canalplus/rx-player/subscription',
#       'commits_url': 'https://api.github.com/repos/canalplus/rx-player/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/canalplus/rx-player/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/canalplus/rx-player/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/canalplus/rx-player/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/canalplus/rx-player/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/canalplus/rx-player/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/canalplus/rx-player/merges',
#       'archive_url': 'https://api.github.com/repos/canalplus/rx-player/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/canalplus/rx-player/downloads',
#       'issues_url': 'https://api.github.com/repos/canalplus/rx-player/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/canalplus/rx-player/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/canalplus/rx-player/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/canalplus/rx-player/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/canalplus/rx-player/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/canalplus/rx-player/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/canalplus/rx-player/deployments',
#       'created_at': '2015-06-18T12:16:05Z',
#       'updated_at': '2019-12-04T18:12:02Z',
#       'pushed_at': '2019-12-05T15:10:01Z',
#       'git_url': 'git://github.com/canalplus/rx-player.git',
#       'ssh_url': 'git@github.com:canalplus/rx-player.git',
#       'clone_url': 'https://github.com/canalplus/rx-player.git',
#       'svn_url': 'https://github.com/canalplus/rx-player',
#       'homepage': 'https://developers.canal-plus.com/rx-player/',
#       'size': 106211,
#       'stargazers_count': 455,
#       'watchers_count': 455,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 64,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 18,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 64,
#       'open_issues': 18,
#       'watchers': 455,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/canalplus/rx-player/pulls/644'},
#      'html': {'href': 'https://github.com/canalplus/rx-player/pull/644'},
#      'issue': {'href': 'https://api.github.com/repos/canalplus/rx-player/issues/644'},
#      'comments': {'href': 'https://api.github.com/repos/canalplus/rx-player/issues/644/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/canalplus/rx-player/pulls/644/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/canalplus/rx-player/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/canalplus/rx-player/pulls/644/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/canalplus/rx-player/statuses/03af6476544d6d935aa1e34d0be775ee83b19cb7'}},
#     'author_association': 'COLLABORATOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 82,
#     'deletions': 24,
#     'changed_files': 7}},
#   'public': True,
#   'created_at': '2019-12-05T15:10:46Z',
#   'org': {'id': 2371279,
#    'login': 'canalplus',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/canalplus',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2371279?'}},
#  {'id': '11020755299',
#   'type': 'CreateEvent',
#   'actor': {'id': 46347439,
#    'login': 'Patrick5455',
#    'display_login': 'Patrick5455',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Patrick5455',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46347439?'},
#   'repo': {'id': 226129206,
#    'name': 'Patrick5455/Learning_Python',
#    'url': 'https://api.github.com/repos/Patrick5455/Learning_Python'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Exercises & Notes',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T15:10:46Z'},
#  {'id': '11020755279',
#   'type': 'PushEvent',
#   'actor': {'id': 40063377,
#    'login': 'empenguin1186',
#    'display_login': 'empenguin1186',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/empenguin1186',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40063377?'},
#   'repo': {'id': 204268419,
#    'name': 'empenguin1186/docs',
#    'url': 'https://api.github.com/repos/empenguin1186/docs'},
#   'payload': {'push_id': 4360043311,
#    'size': 4,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/effective_java',
#    'head': '111950b296e464712bed329b7eb2b3c798859a27',
#    'before': '5cedcd2466207a3b7e05db8f11cf807d1a5f0e7d',
#    'commits': [{'sha': '982d59b8c74014fe61d9a0cb040cb80c5828cfe1',
#      'author': {'email': '40063377+empenguin1186@users.noreply.github.com',
#       'name': 'Kota Odaira'},
#      'message': 'Merge pull request #50 from empenguin1186/feature/effective_java\n\n項目20, 44 追加',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/empenguin1186/docs/commits/982d59b8c74014fe61d9a0cb040cb80c5828cfe1'},
#     {'sha': '789db75686ffd33ad91fd06591ca8002ba4e4eb9',
#      'author': {'email': 'emperorpenguint1186@gmail.com',
#       'name': 'empenguin1186'},
#      'message': ':+1: インターフェースについて項目追加',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/empenguin1186/docs/commits/789db75686ffd33ad91fd06591ca8002ba4e4eb9'},
#     {'sha': '3563178866c89e429277fb4ea89cee3b9f0df755',
#      'author': {'email': '40063377+empenguin1186@users.noreply.github.com',
#       'name': 'Kota Odaira'},
#      'message': 'Merge pull request #51 from empenguin1186/feature/kotlin\n\n:+1: インターフェースについて項目追加',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/empenguin1186/docs/commits/3563178866c89e429277fb4ea89cee3b9f0df755'},
#     {'sha': '111950b296e464712bed329b7eb2b3c798859a27',
#      'author': {'email': 'emperorpenguint1186@gmail.com',
#       'name': 'empenguin1186'},
#      'message': '項目40, 51追加',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/empenguin1186/docs/commits/111950b296e464712bed329b7eb2b3c798859a27'}]},
#   'public': True,
#   'created_at': '2019-12-05T15:10:46Z'},
#  {'id': '11020755280',
#   'type': 'CreateEvent',
#   'actor': {'id': 4197959,
#    'login': 'ozooxo',
#    'display_login': 'ozooxo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ozooxo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4197959?'},
#   'repo': {'id': 226129081,
#    'name': 'restfulci/restfulci',
#    'url': 'https://api.github.com/repos/restfulci/restfulci'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T15:10:46Z',
#   'org': {'id': 58561713,
#    'login': 'restfulci',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/restfulci',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58561713?'}},
#  {'id': '11020755289',
#   'type': 'PushEvent',
#   'actor': {'id': 15197821,
#    'login': 'tsoenen',
#    'display_login': 'tsoenen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tsoenen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15197821?'},
#   'repo': {'id': 170302114,
#    'name': 'tsoenen/tng-sdk-test',
#    'url': 'https://api.github.com/repos/tsoenen/tng-sdk-test'},
#   'payload': {'push_id': 4360043314,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3c705e6bf9d10754f9da7ce97f94e855fe48ed8f',
#    'before': '94ea8d0f70d66a7936390d1f330e584bdaa64567',
#    'commits': [{'sha': '3c705e6bf9d10754f9da7ce97f94e855fe48ed8f',
#      'author': {'email': 'thomas.soenen@ugent.be', 'name': 'Thomas'},
#      'message': 'improving vnv support',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tsoenen/tng-sdk-test/commits/3c705e6bf9d10754f9da7ce97f94e855fe48ed8f'}]},
#   'public': True,
#   'created_at': '2019-12-05T15:10:46Z'},
#  {'id': '11020755286',
#   'type': 'CreateEvent',
#   'actor': {'id': 6673453,
#    'login': 'mbwhite',
#    'display_login': 'mbwhite',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mbwhite',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6673453?'},
#   'repo': {'id': 66573241,
#    'name': 'hyperledger/fabric',
#    'url': 'https://api.github.com/repos/hyperledger/fabric'},
#   'payload': {'ref': 'java-contract-quick-start',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-05T15:10:46Z',
#   'org': {'id': 7657900,
#    'login': 'hyperledger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hyperledger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7657900?'}},
#  {'id': '11020755277',
#   'type': 'PushEvent',
#   'actor': {'id': 47854562,
#    'login': '79donaldson',
#    'display_login': '79donaldson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/79donaldson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47854562?'},
#   'repo': {'id': 223666435,
#    'name': '79donaldson/mytsimpletest',
#    'url': 'https://api.github.com/repos/79donaldson/mytsimpletest'},
#   'payload': {'push_id': 4360043310,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a32c3c29384006d5e09e140508a868c326685c2f',
#    'before': '8fdb469e8f6d6ae4b1e4cd2a2f10d916cac63482',
#    'commits': [{'sha': 'a32c3c29384006d5e09e140508a868c326685c2f',
#      'author': {'email': '79donaldson@gmail.com', 'name': 'Aleksey'},
#      'message': 'schoolapp',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/79donaldson/mytsimpletest/commits/a32c3c29384006d5e09e140508a868c326685c2f'}]},
#   'public': True,
#   'created_at': '2019-12-05T15:10:46Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
payload = {'StationIdentifier':'2560H019'}
r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel',params=payload)
print(r.url)
json.loads(r.text)
# Out:
# http://odata.wra.gov.tw/v4/RealtimeWaterLevel?StationIdentifier=2560H019
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '2560H024',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 202.64},
#   {'StationIdentifier': '2560H022',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 194.54},
#   {'StationIdentifier': '2560H019',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 4.56},
#   {'StationIdentifier': '2500H003',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 32.11},
#   {'StationIdentifier': '2370H024',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 195.44},
#   {'StationIdentifier': '1650H009',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 0.33},
#   {'StationIdentifier': '1630H032',
#    'RecordTime': 'Dec 5, 2019 6:50:00 PM',
#    'WaterLevel': 0.52},
#   {'StationIdentifier': '2420H037',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 133.43},
#   {'StationIdentifier': '1630H029',
#    'RecordTime': 'Dec 5, 2019 6:50:00 PM',
#    'WaterLevel': 4.97},
#   {'StationIdentifier': '2560H006',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 3.25},
#   {'StationIdentifier': '1740H002',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 4.41},
#   {'StationIdentifier': '1730H066',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 138.5},
#   {'StationIdentifier': '1730H074',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 245.49},
#   {'StationIdentifier': '2420H019',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 109.99},
#   {'StationIdentifier': '2420H043',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 79.32},
#   {'StationIdentifier': '1630H028',
#    'RecordTime': 'Dec 5, 2019 6:50:00 PM',
#    'WaterLevel': 10.21},
#   {'StationIdentifier': '1730H076',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 58.07},
#   {'StationIdentifier': '1670H003',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 0.33},
#   {'StationIdentifier': '1730H069',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': -999998},
#   {'StationIdentifier': '2200H011',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 25.82},
#   {'StationIdentifier': '1660H013',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 0.96},
#   {'StationIdentifier': '1630H024',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 69.09},
#   {'StationIdentifier': '1730H071',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 35.33},
#   {'StationIdentifier': '1660H011',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 1.47},
#   {'StationIdentifier': '1730H079',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 548.84},
#   {'StationIdentifier': '1730H062',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 41.76},
#   {'StationIdentifier': '1630H020',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 35.29},
#   {'StationIdentifier': '1650H011',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 0.44},
#   {'StationIdentifier': '1590H013',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 20.8},
#   {'StationIdentifier': '1730H067',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': -999998},
#   {'StationIdentifier': '1650H006',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 1.24},
#   {'StationIdentifier': '1630H013',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 15.54},
#   {'StationIdentifier': '1730H058',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 113.58},
#   {'StationIdentifier': '1590H019',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 14.88},
#   {'StationIdentifier': '1660H009',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 4.85},
#   {'StationIdentifier': '1730H045',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 5.1},
#   {'StationIdentifier': '1580H017',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 25.82},
#   {'StationIdentifier': '1630H035',
#    'RecordTime': 'Dec 5, 2019 6:20:00 PM',
#    'WaterLevel': 402.47},
#   {'StationIdentifier': '1580H020',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 35.62},
#   {'StationIdentifier': '1430H054',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 48.28},
#   {'StationIdentifier': '1590H016',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 11.34},
#   {'StationIdentifier': '1650H014',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 0.98},
#   {'StationIdentifier': '1680H005',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 0.11},
#   {'StationIdentifier': '1550H014',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 26.82},
#   {'StationIdentifier': '1630H026',
#    'RecordTime': 'Dec 5, 2019 6:50:00 PM',
#    'WaterLevel': 44.49},
#   {'StationIdentifier': '1580H013',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 9.72},
#   {'StationIdentifier': '1430H032',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 337.58},
#   {'StationIdentifier': '1590H012',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 2.79},
#   {'StationIdentifier': '1630H037',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 9.34},
#   {'StationIdentifier': '1540H031',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 10.14},
#   {'StationIdentifier': '1550H011',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 0.6},
#   {'StationIdentifier': '1510H063',
#    'RecordTime': 'Dec 5, 2019 7:10:00 PM',
#    'WaterLevel': 263.87},
#   {'StationIdentifier': '1550H018',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 0.62},
#   {'StationIdentifier': '1430H028',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 23.71},
#   {'StationIdentifier': '1580H007',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 23.68},
#   {'StationIdentifier': '1510H084',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 145.04},
#   {'StationIdentifier': '1540H014',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 8.01},
#   {'StationIdentifier': '1540H038',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 54.81},
#   {'StationIdentifier': '1510H050',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 155.63},
#   {'StationIdentifier': '1540H036',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': -999998},
#   {'StationIdentifier': '1430H025',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 10.29},
#   {'StationIdentifier': '1430H038',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 75.59},
#   {'StationIdentifier': '1420H052',
#    'RecordTime': 'Dec 5, 2019 7:10:00 PM',
#    'WaterLevel': 429.96},
#   {'StationIdentifier': '1510H087',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 428.65},
#   {'StationIdentifier': '1540H033',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 23.35},
#   {'StationIdentifier': '1510H081',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 229.09},
#   {'StationIdentifier': '1430H030',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 87.66},
#   {'StationIdentifier': '1350H030',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 57.48},
#   {'StationIdentifier': '1430H057',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 31.85},
#   {'StationIdentifier': '1420H056',
#    'RecordTime': 'Dec 4, 2019 5:50:00 PM',
#    'WaterLevel': 196.52},
#   {'StationIdentifier': '1510H082',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 752.4},
#   {'StationIdentifier': '1430H052',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 173.28},
#   {'StationIdentifier': '1510H057',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 88.53},
#   {'StationIdentifier': '1510H076',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 4.9},
#   {'StationIdentifier': '1350H028',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 232.8},
#   {'StationIdentifier': '1430H061',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 25.07},
#   {'StationIdentifier': '1510H064',
#    'RecordTime': 'Dec 5, 2019 7:10:00 PM',
#    'WaterLevel': 265.16},
#   {'StationIdentifier': '1350H026',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 30.44},
#   {'StationIdentifier': '1430H048',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 166.07},
#   {'StationIdentifier': '1510H088',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 141.08},
#   {'StationIdentifier': '1140H126',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 81.12},
#   {'StationIdentifier': '1420H053',
#    'RecordTime': 'Dec 5, 2019 7:10:00 PM',
#    'WaterLevel': 471.65},
#   {'StationIdentifier': '1430H060',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 20.38},
#   {'StationIdentifier': '1140H095',
#    'RecordTime': 'Dec 5, 2019 7:10:00 PM',
#    'WaterLevel': 110.06},
#   {'StationIdentifier': '1350H023',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 256.36},
#   {'StationIdentifier': '1430H046',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 111.15},
#   {'StationIdentifier': '1510H085',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 279.83},
#   {'StationIdentifier': '1350H019',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 33.68},
#   {'StationIdentifier': '1400H020',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 318.67},
#   {'StationIdentifier': '1430H055',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 78.56},
#   {'StationIdentifier': '1140H067',
#    'RecordTime': 'Dec 5, 2019 7:10:00 PM',
#    'WaterLevel': 29.14},
#   {'StationIdentifier': '1350H012',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 12.47},
#   {'StationIdentifier': '1430H044',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 139.5},
#   {'StationIdentifier': '1400H008',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 479.68},
#   {'StationIdentifier': '1340H013',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 247.12},
#   {'StationIdentifier': '1400H018',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 55.27},
#   {'StationIdentifier': '1300H024',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 29.11},
#   {'StationIdentifier': '1140H107',
#    'RecordTime': 'Dec 5, 2019 7:25:00 PM',
#    'WaterLevel': 2.72},
#   {'StationIdentifier': '2370H004',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 192.72},
#   {'StationIdentifier': '1300H013',
#    'RecordTime': 'Dec 5, 2019 7:20:00 PM',
#    'WaterLevel': 245.74}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
